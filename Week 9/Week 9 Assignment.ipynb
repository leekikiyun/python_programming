# %% [markdown]
# <a href="https://colab.research.google.com/github/leekikiyun/python_programming/blob/main/Week%209/Week%209%20Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 9 Assignment - Functions

# %% [markdown]
# 강의 교안 p.4 ~ p.24의 코드를 Jupyter Notebook에서 입력하고 실행한 결과입니다.

# %% [markdown]
# ## p.4 List Comprehension

# %%
number_list = []
number_list.append(1)
number_list.append(2)
number_list.append(3)
number_list.append(4)
number_list.append(5)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
number_list = []
for number in range(1, 6):
    number_list.append(number)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
number_list = list(range(1, 6))
number_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## p.5 List Comprehension

# %%
number_list = [number for number in range(1, 6)]
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
number_list = [number - 1 for number in range(1, 6)]
number_list
# Out:
# [0, 1, 2, 3, 4]

# %%
a_list = [number for number in range(1, 6) if number % 2 == 1]
a_list
# Out:
# [1, 3, 5]

# %% [markdown]
# ## p.6 for 문으로 작성

# %%
a_list = []
for number in range(1, 6):
    if number % 2 == 1:
        a_list.append(number)
a_list
# Out:
# [1, 3, 5]

# %% [markdown]
# ## p.7 List Comprehension 예제

# %%
sentence = ['I', 'Love', 'Python', 'Soooooo', 'MUCH!!!']
[word.lower() for word in sentence]
# Out:
# ['i', 'love', 'python', 'soooooo', 'much!!!']

# %%
[word for word in sentence if len(word) > 6]
# Out:
# ['Soooooo', 'MUCH!!!']

# %%
[(x, x ** 2, x ** 3) for x in range(10)]
# Out:
# [(0, 0, 0), (1, 1, 1), (2, 4, 8), (3, 9, 27), (4, 16, 64), (5, 25, 125), (6, 36, 216), (7, 49, 343), (8, 64, 512), (9, 81, 729)]

# %% [markdown]
# ## p.8 두 개의 for

# %%
rows = range(1, 4)
cols = range(1, 3)
for row in rows:
    for col in cols:
        print(row, col)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
rows = range(1, 4)
cols = range(1, 3)
cells = [(row, col) for row in rows for col in cols]
for cell in cells:
    print(cell)
# Out:
# (1, 1)
# (1, 2)
# (2, 1)
# (2, 2)
# (3, 1)
# (3, 2)

# %%
[(i, j) for i in range(5) for j in range(i)]
# Out:
# [(1, 0), (2, 0), (2, 1), (3, 0), (3, 1), (3, 2), (4, 0), (4, 1), (4, 2), (4, 3)]

# %% [markdown]
# ## p.9 ~ p.10 Dictionary Comprehension

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in word}
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in set(word)}
letter_counts
# Out:
# {'t': 2, 'r': 1, 's': 1, 'e': 2, 'l': 1}

# %% [markdown]
# ## p.11 Set Comprehension

# %%
a_set = {number for number in range(1, 6) if number % 3 == 1}
a_set
# Out:
# {1, 4}

# %% [markdown]
# ## p.12 Comprehension
#
# 교안의 식을 실행할 수 있도록 예시 딕셔너리와 단어 목록을 먼저 정의했습니다.

# %%
d = {'one': 1, 'two': 2, 'three': 3}
{v: k for k, v in d.items()}
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
def is_palindrome(word):
    return word == word[::-1]

hamlet = ['level', 'Hamlet', 'noon', 'Python', 'civic']
{word for word in hamlet if is_palindrome(word.lower())}
# Out:
# {'noon', 'level', 'civic'}

# %% [markdown]
# ## p.14 Functions - 기본 구조

# %% [markdown]
# 교안의 함수 기본 구조는 다음과 같습니다.
#
# ```python
# def function_name(param1, param2):
#     value = do_something()
#     return value
# ```

# %% [markdown]
# ## p.15 Functions - 예제

# %%
def sum(a, b):
    return a + b

# %%
sum(1, 2)
# Out:
# 3

# %%
sum(1.3, 3.1)
# Out:
# 4.4

# %%
sum('love ', 'python')
# Out:
# 'love python'

# %% [markdown]
# ## p.16 iteration - zip()

# %%
days = ['Monday', 'Tuesday', 'Wednesday']
fruits = ['banana', 'orange', 'peach']
drinks = ['coffee', 'tea', 'beer']
desserts = ['tiramisu', 'ice cream', 'pie', 'pudding']

for day, fruit, drink, dessert in zip(days, fruits, drinks, desserts):
    print(day, ": drink", drink, "- eat", fruit, "- enjoy", dessert)
# Out:
# Monday : drink coffee - eat banana - enjoy tiramisu
# Tuesday : drink tea - eat orange - enjoy ice cream
# Wednesday : drink beer - eat peach - enjoy pie

# %% [markdown]
# ## p.17 iteration - zip()

# %%
english = 'Monday', 'Tuesday', 'Wednesday'
french = 'Lundi', 'Mardi', 'Mercredi'
list(zip(english, french))
# Out:
# [('Monday', 'Lundi'), ('Tuesday', 'Mardi'), ('Wednesday', 'Mercredi')]

# %%
dict(zip(english, french))
# Out:
# {'Monday': 'Lundi', 'Tuesday': 'Mardi', 'Wednesday': 'Mercredi'}

# %% [markdown]
# ## p.18 함수 위치 인자

# %%
def menu(wine, entree, dessert):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

# %%
menu('chardonnay', 'chicken', 'cake')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'cake'}

# %% [markdown]
# ## p.19 함수 키워드 인자

# %%
menu(entree='beef', dessert='bagel', wine='bordeaux')
# Out:
# {'wine': 'bordeaux', 'entree': 'beef', 'dessert': 'bagel'}

# %%
menu('frontenac', dessert='flan', entree='fish')
# Out:
# {'wine': 'frontenac', 'entree': 'fish', 'dessert': 'flan'}

# %% [markdown]
# ## p.20 기본 매개변수 값 정하기

# %%
def menu(wine, entree, dessert='pudding'):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

# %%
menu('chardonnay', 'chicken')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %%
menu('dunkelfelder', 'duck', 'doughnut')
# Out:
# {'wine': 'dunkelfelder', 'entree': 'duck', 'dessert': 'doughnut'}

# %% [markdown]
# ## p.21 가능한 함수 호출

# %%
def menu(price, wine='chardonnay', entree='chicken', dessert='pudding'):
    return {
        'price': price,
        'wine': wine,
        'entree': entree,
        'dessert': dessert,
    }

# %%
menu(100)
# Out:
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %%
menu(price=100)
# Out:
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %%
menu(price=120, entree='beef')
# Out:
# {'price': 120, 'wine': 'chardonnay', 'entree': 'beef', 'dessert': 'pudding'}

# %%
menu(dessert='bagel', price=110)
# Out:
# {'price': 110, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'bagel'}

# %%
menu('eighty', 'saint-pierre', 'fish')
# Out:
# {'price': 'eighty', 'wine': 'saint-pierre', 'entree': 'fish', 'dessert': 'pudding'}

# %%
menu('hundred', wine='saint-pierre')
# Out:
# {'price': 'hundred', 'wine': 'saint-pierre', 'entree': 'chicken', 'dessert': 'pudding'}

# %% [markdown]
# ## p.22 불가능한 함수 호출
#
# 오류 예제도 전체 노트북이 중단되지 않도록 예외 메시지를 출력했습니다.

# %%
try:
    menu()
except TypeError as error:
    print(type(error).__name__ + ':', error)
# Out:
# TypeError: menu() missing 1 required positional argument: 'price'

# %%
try:
    exec("menu(price=100, 'saint-pierre')")
except SyntaxError as error:
    print(type(error).__name__ + ':', error.msg)
# Out:
# SyntaxError: positional argument follows keyword argument

# %%
try:
    menu(100, price=120)
except TypeError as error:
    print(type(error).__name__ + ':', error)
# Out:
# TypeError: menu() got multiple values for argument 'price'

# %%
try:
    menu(main='cream pasta')
except TypeError as error:
    print(type(error).__name__ + ':', error)
# Out:
# TypeError: menu() got an unexpected keyword argument 'main'

# %% [markdown]
# ## p.23 docstring

# %%
def echo(anything):
    'echo returns its input argument'
    return anything

# %%
def print_if_true(thing, check):
    """
    Prints the first argument if a second argument is true.
    The operation is:
    1. Check whether the *second* argument is true.
    2. If it is, print the *first* argument.
    """
    if check:
        print(thing)

# %%
echo('Hello')
# Out:
# 'Hello'

# %%
print_if_true('This is true.', True)
# Out:
# This is true.

# %% [markdown]
# ## p.24 docstring 확인

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(anything)
#     echo returns its input argument

# %%
print(echo.__doc__)
# Out:
# echo returns its input argument
