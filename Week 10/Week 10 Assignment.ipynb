# %% [markdown]
# <a href="https://colab.research.google.com/github/leekikiyun/python_programming/blob/main/Week%2010/Week%2010%20Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 10 Assignment - Classes

# %% [markdown]
# 강의 교안 p.11 ~ p.31의 코드를 Jupyter Notebook에서 입력하고 실행한 결과입니다.

# %% [markdown]
# ## p.11 계산기 더하기 기능

# %%
result = 0

def adder(num):
    global result
    result += num
    return result

# %%
print(adder(3))
# Out:
# 3

# %%
print(adder(4))
# Out:
# 7

# %% [markdown]
# ## p.12 계산기가 두 개 필요하다면

# %%
result1 = 0
result2 = 0

def adder1(num):
    global result1
    result1 += num
    return result1

def adder2(num):
    global result2
    result2 += num
    return result2

# %%
print(adder1(3))
print(adder1(4))
print(adder2(3))
print(adder2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ## p.13 클래스 사용

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def adder(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.adder(3))
print(cal1.adder(4))
print(cal2.adder(3))
print(cal2.adder(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ## p.14 객체와 인스턴스

# %% [markdown]
# `cal1`은 객체이며, `Calculator` 클래스로 만든 인스턴스입니다.

# %% [markdown]
# ## p.15 클래스 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()
an.secret
# Out:
# '지구는 4006년에 멸망한다.'

# %% [markdown]
# ## p.16 클래스 변수 공유

# %%
Service.secret
# Out:
# '지구는 4006년에 멸망한다.'

# %%
Service.secret = '지구가 4006년에 멸망한다는 사실은 뻥이다.'
print(an.secret)
# Out:
# 지구가 4006년에 멸망한다는 사실은 뻥이다.

# %% [markdown]
# ## p.17 ~ p.18 클래스 내부의 함수(메서드)

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def sum(self, a, b):
        result = a + b
        print("%s + %s = %s이다." % (a, b, result))

an = Service()
an.sum(1, 1)
# Out:
# 1 + 1 = 2이다.

# %% [markdown]
# ## p.19 객체 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service()
an.setname("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# ## p.20 클래스 변수와 객체 변수

# %%
kim = Service()
park = Service()
kim.name = "김정보"
park.name = "박용함"

print(kim.name)
print(park.name)

kim.secret = "비밀은 없다"
print(park.secret)
print(kim.secret)
print(Service.secret)
# Out:
# 김정보
# 박용함
# 지구는 4006년에 멸망한다.
# 비밀은 없다
# 지구는 4006년에 멸망한다.

# %% [markdown]
# ## p.21 __init__이 필요한 이유

# %%
lee = Service()
try:
    lee.sum(1, 1)
except AttributeError as error:
    print(type(error).__name__ + ':', error)
# Out:
# AttributeError: 'Service' object has no attribute 'name'

# %% [markdown]
# ## p.22 __init__

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def __init__(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# ## p.23 클래스 구조

# %% [markdown]
# 클래스에는 클래스 변수와 메서드를 정의할 수 있으며, 메서드의 첫 번째 매개변수로 보통 `self`를 사용합니다.

# %% [markdown]
# ## p.24 사칙연산 클래스

# %%
class FourCal:
    pass

a = FourCal()
type(a)
# Out:
# <class '__main__.FourCal'>

# %% [markdown]
# ## p.25 사칙연산 클래스 - 데이터 세팅

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

a = FourCal()
a.setdata(4, 2)
print(a.first)
print(a.second)
# Out:
# 4
# 2

# %% [markdown]
# ## p.26 사칙연산 클래스 - 더하기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

a = FourCal()
a.setdata(4, 2)
print(a.sum())
# Out:
# 6

# %% [markdown]
# ## p.27 사칙연산 클래스

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        return self.first + self.second

    def mul(self):
        return self.first * self.second

    def sub(self):
        return self.first - self.second

    def div(self):
        return self.first / self.second

a = FourCal()
b = FourCal()
a.setdata(4, 2)
b.setdata(3, 7)

print(a.sum())
print(a.mul())
print(a.sub())
print(a.div())
print(b.sub())
# Out:
# 6
# 8
# 2
# 2.0
# -4

# %% [markdown]
# ## p.28 Class example

# %% [markdown]
# ## p.29 간단한 주사위 게임

# %% [markdown]
# 두 명의 플레이어가 세 개의 주사위를 굴리고, 더 높은 합계를 얻은 플레이어가 이깁니다.

# %% [markdown]
# ## p.30 순차적 프로그래밍

# %%
import random

player1_dice = []
player2_dice = []

for i in range(3):
    player1_dice.append(random.randint(1, 6))
    player1_dice.append(random.randint(1, 6))

print("Player 1 rolled" + str(player1_dice))
print("Player 2 rolled" + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice) > sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled[1, 5, 5, 6, 2, 6]
# Player 2 rolled[]
# Player 1 wins

# %% [markdown]
# ## p.31 OOP

# %%
from random import randint

class Player:
    def __init__(self):
        self.dice = []

    def roll(self):
        self.dice = []
        for i in range(3):
            self.dice.append(randint(1, 6))

    def get_dice(self):
        return self.dice

player1 = Player()
player2 = Player()

player1.roll()
player2.roll()

print("Player 1 rolled" + str(player1.get_dice()))
print("Player 2 rolled" + str(player2.get_dice()))

if sum(player1.get_dice()) == sum(player2.get_dice()):
    print("Draw!")
elif sum(player1.get_dice()) > sum(player2.get_dice()):
    print("Player 1 wins!")
else:
    print("Player 2 wins!")
# Out:
# Player 1 rolled[4, 2, 1]
# Player 2 rolled[5, 3, 6]
# Player 2 wins!
